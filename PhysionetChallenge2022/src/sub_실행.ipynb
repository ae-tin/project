# %%
# !python train_model.py /Data1/physionet/data_split/murmur/train/ sub_model1
# Out:
# Finding data files...
# Extracting features and labels from the Challenge data...
# 100%|█████████████████████████████████████████| 751/751 [00:18<00:00, 41.36it/s]
# <class 'numpy.ndarray'>
# (120, 313)
# 2553
# - 2532 murmur training samples
# - 80 murmur training batches
# - 2553 outcome training samples
# - 80 outcome training batches
# 08-11 04:05 [MainProcess, 11808] [DEBUG]  Starting new HTTPS connection (1): huggingface.co:443
# 08-11 04:05 [MainProcess, 11808] [DEBUG]  https://huggingface.co:443 "HEAD /facebook/wav2vec2-base-960h/resolve/main/preprocessor_config.json HTTP/1.1" 200 0
# 08-11 04:05 [MainProcess, 11808] [DEBUG]  Starting new HTTPS connection (1): huggingface.co:443
# 08-11 04:05 [MainProcess, 11808] [DEBUG]  https://huggingface.co:443 "GET /api/models/facebook/wav2vec2-base-960h HTTP/1.1" 200 2854
# 08-11 04:05 [MainProcess, 11808] [DEBUG]  Starting new HTTPS connection (1): huggingface.co:443
# ...

# %%
# !python run_model.py sub_model1 /Data1/physionet/data_split/murmur/test/ sub_output1
# Out:
# Loading Challenge model...
# t
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# *************** load weight ***************
# Running model on Challenge data...
# 100%|█████████████████████████████████████████| 191/191 [01:23<00:00,  2.30it/s]
# Done.

# %%
# !python evaluate_model.py /Data1/physionet/data_split/murmur/test sub_output1 scores_sub1.csv

# %%
# !cat scores_sub1.csv
# Out:
# #Murmur scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.770,0.639,0.544,0.817,0.809,17789.520
#
# #Outcome scores
# AUROC,AUPRC,F-measure,Accuracy,Weighted Accuracy,Cost
# 0.681,0.673,0.623,0.623,0.623,13401.013
#
# #Murmur scores (per class)
# Classes,Present,Unknown,Absent
# AUROC,0.972,0.500,0.838
# AUPRC,0.928,0.073,0.914
# F-measure,0.750,0.000,0.882
# Accuracy,0.947,0.000,0.863
#
# #Outcome scores (per class)
# Classes,Abnormal,Normal
# AUROC,0.681,0.681
# AUPRC,0.721,0.624
# F-measure,0.629,0.617
# Accuracy,0.622,0.624

# %%
python evaluate_model.py /Data1/physionet/data_split/murmur/test sub_output_last scores_sub_last.csv
