# %% [markdown]
# # Thread - 쓰레드
#
# 프로그램이 실행됐을 때 작업을 수행하는 단위
# 일반적으로 하나의 프로그램은 하나의 스레드를 가지고 있지만 둘 이상의 스레드를 동시에 실행할 수도 있다.
# 파이썬에서는 함수를 만들고 함수를 스레드 모듈로 실행시키면 해당 함수는 스레드로 동작한다.

# %%
import threading

def func1():
    total = 0
    for i in range(0,101,1):
        total = total + i
        print("함수 1번 : " + str(total))

        
def func2():
    total = 0
    for i in range(100,0,-1):
        total = total + i
        print("함수 2번 : " + str(total))

t1 = threading.Thread(target=func1)
t2 = threading.Thread(target=func2)

t1.start()
t2.start()
# Out:
# 함수 1번 : 0
# 함수 1번 : 1
# 함수 1번 : 3
# 함수 1번 : 6
# 함수 1번 : 10
# 함수 1번 : 15
# 함수 1번 : 21
# 함수 1번 : 28
# 함수 1번 : 36
# 함수 1번 : 45
# 함수 1번 : 55
# 함수 1번 : 66
# 함수 1번 : 78
# 함수 1번 : 91
# 함수 1번 : 105
# 함수 1번 : 120
# 함수 1번 : 136
# 함수 1번 : 153
# 함수 1번 : 171
# 함수 1번 : 190
# 함수 1번 : 210
# 함수 1번 : 231
# 함수 1번 : 253
# 함수 1번 : 276
# 함수 1번 : 300
# 함수 1번 : 325
# 함수 2번 : 100
# 함수 2번 : 199함수 1번 : 351
# 함수 1번 : 378
# 함수 1번 : 406
# 함수 1번 : 435
# 함수 1번 : 465
# 함수 1번 : 496
# 함수 1번 : 528
#
# 함수 2번 : 297
# 함수 2번 : 394
# 함수 2번 : 490
# 함수 2번 : 585
# 함수 2번 : 679
# 함수 2번 : 772함수 1번 : 561
# 함수 1번 : 595
# 함수 1번 : 630
# 함수 1번 : 666
# 함수 1번 : 703
#
# 함수 2번 : 864
# 함수 2번 : 955
# 함수 2번 : 1045
# 함수 2번 : 1134
# 함수 2번 : 1222
# 함수 2번 : 1309
# 함수 2번 : 1395
# 함수 2번 : 1480
# 함수 2번 : 1564
# 함수 2번 : 1647
# 함수 2번 : 1729
# 함수 2번 : 1810
# 함수 2번 : 1890
# 함수 2번 : 1969
# 함수 2번 : 2047
# 함수 2번 : 2124
# 함수 2번 : 2200
# 함수 2번 : 2275
# 함수 2번 : 2349
# 함수 2번 : 2422
# 함수 2번 : 2494
# 함수 2번 : 2565
# 함수 2번 : 2635
# 함수 2번 : 2704
# 함수 2번 : 2772
# 함수 2번 : 2839
# 함수 2번 : 2905
# 함수 2번 : 2970함수 1번 : 741
# 함수 2번 : 3034
# 함수 1번 : 780
# 함수 1번 : 820
# 함수 1번 : 861
# 함수 1번 : 903
# 함수 1번 : 946
# 함수 1번 : 990
# 함수 1번 : 1035
# 함수 1번 : 1081
# 함수 1번 : 1128
# 함수 1번 : 1176
# 함수 1번 : 1225
# 함수 1번 : 1275
# 함수 1번 : 1326
# 함수 1번 : 1378
# 함수 1번 : 1431
# 함수 1번 : 1485
# 함수 1번 : 1540
# 함수 1번 : 1596
# 함수 1번 : 1653
# 함수 1번 : 1711
# 함수 1번 : 1770
# 함수 1번 : 1830
# 함수 1번 : 1891
# 함수 1번 : 1953
# 함수 1번 : 2016
# 함수 1번 : 2080
# 함수 1번 : 2145
# 함수 1번 : 2211
# 함수 1번 : 2278
# 함수 1번 : 2346
# 함수 1번 : 2415
# 함수 1번 : 2485
# 함수 1번 : 2556
# 함수 1번 : 2628
# 함수 1번 : 2701
# 함수 1번 : 2775
# 함수 1번 : 2850
#
# 함수 1번 : 2926
# 함수 1번 : 3003
# 함수 1번 : 3081
# 함수 1번 : 3160
# 함수 1번 : 3240
# 함수 1번 : 3321
# 함수 1번 : 3403
# 함수 1번 : 3486
# 함수 1번 : 3570
# 함수 1번 : 3655
# 함수 1번 : 3741
# 함수 1번 : 3828
# 함수 1번 : 3916
# 함수 1번 : 4005함수 2번 : 3097
# 함수 2번 : 3159
# 함수 2번 : 3220
#
# 함수 1번 : 4095
# 함수 1번 : 4186
# 함수 1번 : 4278
# 함수 1번 : 4371
# 함수 1번 : 4465
# 함수 1번 : 4560
# 함수 1번 : 4656
# 함수 1번 : 4753
# 함수 1번 : 4851함수 2번 : 3280
# 함수 2번 : 3339
# 함수 2번 : 3397
# 함수 2번 : 3454
#
# 함수 1번 : 4950
# 함수 1번 : 5050
# 함수 2번 : 3510
# 함수 2번 : 3565
# 함수 2번 : 3619
# 함수 2번 : 3672
# 함수 2번 : 3724
# 함수 2번 : 3775
# 함수 2번 : 3825
# 함수 2번 : 3874
# 함수 2번 : 3922
# 함수 2번 : 3969
# 함수 2번 : 4015
# 함수 2번 : 4060
# 함수 2번 : 4104
# 함수 2번 : 4147
# 함수 2번 : 4189
# 함수 2번 : 4230
# 함수 2번 : 4270
# 함수 2번 : 4309
# 함수 2번 : 4347
# 함수 2번 : 4384
# 함수 2번 : 4420
# 함수 2번 : 4455
# 함수 2번 : 4489
# 함수 2번 : 4522
# 함수 2번 : 4554
# 함수 2번 : 4585
# 함수 2번 : 4615
# 함수 2번 : 4644
# 함수 2번 : 4672
# 함수 2번 : 4699
# 함수 2번 : 4725
# 함수 2번 : 4750
# 함수 2번 : 4774
# 함수 2번 : 4797
# 함수 2번 : 4819
# 함수 2번 : 4840
# 함수 2번 : 4860
# 함수 2번 : 4879
# 함수 2번 : 4897
# 함수 2번 : 4914
# 함수 2번 : 4930
# 함수 2번 : 4945
# 함수 2번 : 4959
# 함수 2번 : 4972
# 함수 2번 : 4984
# 함수 2번 : 4995
# 함수 2번 : 5005
# 함수 2번 : 5014
# 함수 2번 : 5022
# 함수 2번 : 5029
# 함수 2번 : 5035
# 함수 2번 : 5040
# 함수 2번 : 5044
# 함수 2번 : 5047
# 함수 2번 : 5049
# 함수 2번 : 5050
