# %%
# !nvidia-smi
# Out:
# Wed Aug  3 07:16:08 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   28C    P8    25W / 260W |    478MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# 08-03 07:16:16 Model para number = 27.12
# 0it [00:00, ?it/s]08-03 07:16:18 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 14.13202, ACC: 0.00%
# 1it [00:02,  2.40s/it]08-03 07:16:20 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 14.22308, ACC: 0.00%
# 2it [00:04,  2.38s/it]08-03 07:16:23 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 14.05691, ACC: 0.00%
# 3it [00:07,  2.38s/it]08-03 07:16:25 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.85337, ACC: 0.00%
# 4it [00:09,  2.37s/it]08-03 07:16:28 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 13.63922, ACC: 0.00%
# 5it [00:11,  2.37s/it]08-03 07:16:30 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 13.46286, ACC: 0.00%
# 6it [00:14,  2.37s/it]08-03 07:16:32 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 13.29986, ACC: 0.00%
# 7it [00:16,  2.38s/it]08-03 07:16:35 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 13.14084, ACC: 0.00%
# ...
