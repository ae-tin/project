# %%
# !nvidia-smi
# Out:
# Mon Jul 25 07:40:16 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   28C    P8    25W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel.py
# Out:
# Available devices  5
# Device: cuda:1
# Current cuda device: 1
# 07-25 07:40:21 Model para number = 14.73
# ********* weight ******** :
# tensor([[-6.6294e-02,  2.8177e-02,  7.7332e-02, -2.3936e-02, -1.1359e-02,
#          -2.9736e-02,  1.0707e-01, -1.0116e-01, -1.1160e-01, -5.2929e-02,
#           1.9124e-02,  7.8554e-02,  4.6079e-02, -4.2405e-02,  7.7154e-02,
#          -1.1558e-02,  9.1678e-02, -2.5929e-02,  6.1234e-02, -3.3244e-02,
#          -1.4518e-02, -4.4904e-02, -5.0746e-02, -6.1943e-02, -3.1227e-03,
#          -4.2676e-02,  5.3934e-02, -9.9348e-02,  8.7432e-02,  8.6988e-02,
#          -9.6933e-02, -1.8924e-02, -3.1377e-02,  4.7835e-02,  1.1084e-01,
#          -3.7436e-02,  7.9217e-02, -5.6259e-02, -8.8180e-02,  3.3640e-02,
#           5.2885e-02,  1.3584e-03,  6.1211e-02,  3.9135e-02,  3.2002e-02,
#          -6.4942e-02, -5.7950e-02, -1.0104e-01,  3.6179e-02,  9.1993e-02,
#           2.6817e-02,  4.0120e-02,  1.0873e-01,  5.4915e-03, -3.6635e-02,
# ...

# %%
(data - np.min(data)) / (np.max(data) - np.min(data))

# %%
import torch
x = torch.rand((1,2,3))
mini,_ = torch.min(x,dim=2,keepdim=True)
maxi,_ = torch.max(x,dim=2,keepdim=True)
n = (x - mini)/(maxi - mini)
(x - torch.min(x,dim=2,keepdim=True))/(torch.max(x,dim=2,keepdim=True) - torch.min(x,dim=2,keepdim=True))
print(x)
print(n)
print(n.permute(0,2,1))
print(mini)
print(mini.shape)
print(maxi)
print(maxi.shape)
# Out:
# tensor([[[0.8740, 0.5860, 0.4727],
#          [0.5960, 0.1480, 0.7695]]])
# tensor([[[1.0000, 0.2825, 0.0000],
#          [0.7209, 0.0000, 1.0000]]])
# tensor([[[1.0000, 0.7209],
#          [0.2825, 0.0000],
#          [0.0000, 1.0000]]])
# tensor([[[0.4727],
#          [0.1480]]])
# torch.Size([1, 2, 1])
# tensor([[[0.8740],
#          [0.7695]]])
# torch.Size([1, 2, 1])

# %%
weight = weight.unsqueeze(0).unsqueeze(2).expand_as(x)

# %%
weight.shape
# Out:
# torch.Size([64, 80, 200])

# %%
a = x*weight

# %%
a.shape
# Out:
# torch.Size([64, 80, 200])
