# %%
# !nvidia-smi
# Out:
# Mon Oct 17 04:27:40 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   27C    P8    25W / 260W |  48466MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel.py
# Out:
# Available devices  5
# Device: cuda:1
# Current cuda device: 1
# 10-17 04:27:51 Model para number = 14.92
# 0it [00:00, ?it/s]10-17 04:27:54 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.96179, ACC: 0.00%
# 1it [00:02,  2.74s/it]10-17 04:27:56 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.62271, ACC: 0.12%
# 2it [00:05,  2.74s/it]10-17 04:27:59 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.34610, ACC: 0.08%
# 3it [00:08,  2.73s/it]10-17 04:28:02 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.03940, ACC: 0.06%
# 4it [00:10,  2.72s/it]10-17 04:28:05 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.82921, ACC: 0.05%
# 5it [00:13,  2.73s/it]10-17 04:28:07 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.65285, ACC: 0.04%
# 6it [00:16,  2.73s/it]10-17 04:28:10 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.49400, ACC: 0.04%
# 7it [00:19,  2.73s/it]10-17 04:28:13 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.35077, ACC: 0.03%
# ...
