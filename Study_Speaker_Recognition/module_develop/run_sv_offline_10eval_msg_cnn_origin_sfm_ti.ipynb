# %%
# !nvidia-smi
# Out:
# Sat Oct 22 11:39:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   27C    P8    24W / 260W |   1540MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel.py
# Out:
# Available devices  5
# Device: cuda:0
# Current cuda device: 0
# 10-22 11:39:58 Model para number = 27.26
# 0it [00:00, ?it/s]10-22 11:40:01 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.90715, ACC: 0.00%
# 1it [00:02,  2.79s/it]10-22 11:40:03 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.84807, ACC: 0.00%
# 2it [00:05,  2.51s/it]10-22 11:40:06 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.57864, ACC: 0.00%
# 3it [00:07,  2.41s/it]10-22 11:40:08 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.35823, ACC: 0.00%
# 4it [00:09,  2.37s/it]10-22 11:40:10 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 13.18210, ACC: 0.00%
# 5it [00:12,  2.35s/it]10-22 11:40:13 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 13.01479, ACC: 0.00%
# 6it [00:14,  2.34s/it]10-22 11:40:15 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.86504, ACC: 0.00%
# 7it [00:16,  2.33s/it]10-22 11:40:17 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.71794, ACC: 0.00%
# ...
