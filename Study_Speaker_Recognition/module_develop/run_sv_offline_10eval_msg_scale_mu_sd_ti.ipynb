# %%
# !nvidia-smi
# Out:
# Tue Dec 20 02:38:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 38%   63C    P2   261W / 260W |  11903MiB / 48601MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel_scale.py
# Out:
# Available devices  5
# Device: cuda:4
# Current cuda device: 4
# 12-20 04:05:14 Model para number = 44.19
# 0it [00:00, ?it/s]12-20 04:05:19 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 14.08345, ACC: 0.00%
# 1it [00:05,  5.52s/it]12-20 04:05:25 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.77800, ACC: 0.12%
# 2it [00:10,  5.41s/it]12-20 04:05:30 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.42217, ACC: 0.08%
# 3it [00:16,  5.36s/it]12-20 04:05:35 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.18367, ACC: 0.06%
# 4it [00:21,  5.35s/it]12-20 04:05:41 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.92225, ACC: 0.05%
# 5it [00:26,  5.36s/it]12-20 04:05:46 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.72934, ACC: 0.04%
# 6it [00:32,  5.34s/it]12-20 04:05:51 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.57889, ACC: 0.04%
# 7it [00:37,  5.34s/it]12-20 04:05:57 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.44110, ACC: 0.03%
# ...
