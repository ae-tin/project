# %%
# !nvidia-smi
# Out:
# Tue Aug 16 15:59:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   28C    P8    25W / 260W |  48122MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# 08-16 15:59:10 Model para number = 27.12
# 0it [00:00, ?it/s]08-16 15:59:13 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.95897, ACC: 0.00%
# 1it [00:02,  2.26s/it]08-16 15:59:15 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.81202, ACC: 0.00%
# 2it [00:04,  2.24s/it]08-16 15:59:17 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.60689, ACC: 0.00%
# 3it [00:06,  2.23s/it]08-16 15:59:19 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.36353, ACC: 0.00%
# 4it [00:08,  2.23s/it]08-16 15:59:22 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 13.16747, ACC: 0.00%
# 5it [00:11,  2.23s/it]08-16 15:59:24 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.98213, ACC: 0.00%
# 6it [00:13,  2.24s/it]08-16 15:59:26 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.82234, ACC: 0.00%
# 7it [00:15,  2.24s/it]08-16 15:59:28 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.68620, ACC: 0.00%
# ...
