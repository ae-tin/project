# %%
# !nvidia-smi
# Out:
# Tue Aug 23 08:59:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   46C    P2   131W / 260W |  48122MiB / 48601MiB |     66%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
import numpy as np
a = np.array([[1,2,3],[1,2,5]])
print(a[0])
# Out:
# [1 2 3]

# %%
# !python trainECAPAModel_mfcc.py
# Out:
# Available devices  5
# Device: cuda:4
# Current cuda device: 4
# 08-23 09:12:15 Model para number = 14.53
# 0it [00:00, ?it/s]08-23 09:12:17 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 14.04369, ACC: 0.00%
# 1it [00:01,  1.74s/it]08-23 09:12:19 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.81299, ACC: 0.00%
# 2it [00:03,  1.69s/it]08-23 09:12:20 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.50011, ACC: 0.00%
# 3it [00:05,  1.68s/it]08-23 09:12:22 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.20006, ACC: 0.00%
# 4it [00:06,  1.66s/it]08-23 09:12:24 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.96631, ACC: 0.00%
# 5it [00:08,  1.66s/it]08-23 09:12:25 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.76952, ACC: 0.00%
# 6it [00:10,  1.66s/it]08-23 09:12:27 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.59442, ACC: 0.04%
# 7it [00:11,  1.66s/it]08-23 09:12:29 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.45445, ACC: 0.03%
# ...
