# %%
# !nvidia-smi
# Out:
# Tue Dec 20 04:09:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 37%   62C    P2   251W / 260W |  11903MiB / 48601MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel_scale.py
# Out:
# Available devices  5
# Device: cuda:2
# Current cuda device: 2
# 12-20 04:13:21 Model para number = 31.04
# 0it [00:00, ?it/s]12-20 04:13:26 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.99390, ACC: 0.00%
# 1it [00:04,  5.00s/it]12-20 04:13:31 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.71407, ACC: 0.00%
# 2it [00:09,  4.99s/it]12-20 04:13:36 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.33979, ACC: 0.00%
# 3it [00:14,  4.99s/it]12-20 04:13:41 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.11224, ACC: 0.00%
# 4it [00:19,  5.00s/it]12-20 04:13:46 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.94553, ACC: 0.00%
# 5it [00:24,  5.00s/it]12-20 04:13:51 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.76205, ACC: 0.00%
# 6it [00:30,  5.06s/it]12-20 04:13:56 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.60668, ACC: 0.00%
# 7it [00:35,  5.02s/it]12-20 04:14:01 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.46268, ACC: 0.00%
# ...
