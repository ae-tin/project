# %%
# !nvidia-smi
# Out:
# Mon Aug 22 14:19:02 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   42C    P2   117W / 260W |  48595MiB / 48601MiB |     47%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# 08-22 14:19:14 Model para number = 27.12
# 0it [00:00, ?it/s]08-22 14:19:17 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.95388, ACC: 0.00%
# 1it [00:02,  2.93s/it]08-22 14:19:20 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.73232, ACC: 0.12%
# 2it [00:05,  2.76s/it]08-22 14:19:23 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.57122, ACC: 0.08%
# 3it [00:08,  2.72s/it]08-22 14:19:25 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.30152, ACC: 0.06%
# 4it [00:10,  2.70s/it]08-22 14:19:28 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 13.05004, ACC: 0.05%
# 5it [00:13,  2.69s/it]08-22 14:19:31 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.83883, ACC: 0.04%
# 6it [00:16,  2.67s/it]08-22 14:19:33 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.68799, ACC: 0.04%
# 7it [00:18,  2.67s/it]08-22 14:19:36 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.52228, ACC: 0.03%
# ...
