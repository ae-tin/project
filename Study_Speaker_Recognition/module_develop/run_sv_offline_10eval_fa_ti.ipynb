# %%
# !nvidia-smi
# Out:
# Tue Jul 12 09:04:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   28C    P8    25W / 260W |   5450MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel.py
# Out:
# Available devices  5
# Device: cuda:0
# Current cuda device: 0
# 07-12 09:04:30 Model para number = 14.73
# 0it [00:00, ?it/s]07-12 09:04:31 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.90288, ACC: 0.00%
# 1it [00:01,  1.22s/it]07-12 09:04:32 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.58930, ACC: 0.00%
# 2it [00:02,  1.17s/it]07-12 09:04:33 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.36472, ACC: 0.00%
# 3it [00:03,  1.16s/it]07-12 09:04:35 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.11387, ACC: 0.00%
# 4it [00:04,  1.15s/it]07-12 09:04:36 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.89895, ACC: 0.00%
# 5it [00:05,  1.15s/it]07-12 09:04:37 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.70339, ACC: 0.00%
# 6it [00:06,  1.14s/it]07-12 09:04:38 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.60462, ACC: 0.00%
# 7it [00:08,  1.14s/it]07-12 09:04:39 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.48326, ACC: 0.00%
# ...
