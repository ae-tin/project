# %%
# !nvidia-smi
# Out:
# Wed Jul 13 02:22:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 34%   27C    P8    25W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel_mfcc.py
# Out:
# Available devices  5
# Device: cuda:4
# Current cuda device: 4
# 08-23 09:15:54 Model para number = 14.53
# 0it [00:00, ?it/s]08-23 09:15:56 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 14.04896, ACC: 0.00%
# 1it [00:02,  2.41s/it]08-23 09:15:58 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.57614, ACC: 0.00%
# 2it [00:04,  2.17s/it]08-23 09:16:00 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.19451, ACC: 0.08%
# 3it [00:06,  2.09s/it]08-23 09:16:02 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 12.91141, ACC: 0.06%
# 4it [00:08,  2.23s/it]08-23 09:16:05 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.69873, ACC: 0.05%
# 5it [00:11,  2.29s/it]08-23 09:16:07 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.51557, ACC: 0.04%
# 6it [00:13,  2.20s/it]08-23 09:16:09 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.35994, ACC: 0.04%
# 7it [00:15,  2.16s/it]08-23 09:16:11 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.21971, ACC: 0.03%
# ...
