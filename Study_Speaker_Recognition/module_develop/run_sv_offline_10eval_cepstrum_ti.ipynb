# %%
# !nvidia-smi
# Out:
# Wed Aug 24 10:16:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 34%   27C    P8    24W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel_mfcc.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# 08-24 10:16:44 Model para number = 14.73
# 0it [00:00, ?it/s]08-24 10:16:46 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.97122, ACC: 0.00%
# 1it [00:01,  1.97s/it]08-24 10:16:48 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 14.04428, ACC: 0.00%
# 2it [00:03,  1.93s/it]08-24 10:16:50 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.82742, ACC: 0.00%
# 3it [00:05,  1.92s/it]08-24 10:16:52 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.63965, ACC: 0.00%
# 4it [00:07,  1.91s/it]08-24 10:16:54 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 13.46178, ACC: 0.00%
# 5it [00:09,  1.92s/it]08-24 10:16:56 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 13.31179, ACC: 0.00%
# 6it [00:11,  1.92s/it]08-24 10:16:58 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 13.20090, ACC: 0.00%
# 7it [00:13,  1.92s/it]08-24 10:17:00 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 13.03731, ACC: 0.00%
# ...

# %%
if 1 :
    print('a')
if 0 :
    print('b')
# Out:
# a
