# %%
# !nvidia-smi
# Out:
# Wed Jul 13 02:22:39 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 34%   27C    P8    25W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# 07-13 02:22:45 Model para number = 14.73
# 0it [00:00, ?it/s]07-13 02:22:46 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.91389, ACC: 0.00%
# 1it [00:01,  1.40s/it]07-13 02:22:47 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.40606, ACC: 0.12%
# 2it [00:02,  1.39s/it]07-13 02:22:49 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.15689, ACC: 0.08%
# 3it [00:04,  1.37s/it]07-13 02:22:50 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 12.90959, ACC: 0.06%
# 4it [00:05,  1.36s/it]07-13 02:22:51 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.69880, ACC: 0.05%
# 5it [00:06,  1.36s/it]07-13 02:22:53 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.51853, ACC: 0.04%
# 6it [00:08,  1.36s/it]07-13 02:22:54 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.37371, ACC: 0.04%
# 7it [00:09,  1.35s/it]07-13 02:22:56 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.22504, ACC: 0.03%
# ...
