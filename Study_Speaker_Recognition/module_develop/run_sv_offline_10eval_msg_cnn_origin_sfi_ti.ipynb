# %%
# !nvidia-smi
# Out:
# Fri Aug  5 18:26:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   28C    P8    25W / 260W |      3MiB / 48601MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel_distill.py
# Out:
# Available devices  5
# Device: cuda:0
# Current cuda device: 0
# 08-05 18:26:59 Model para number = 27.12
# before :  torch.Size([1, 80, 1])
# 0it [00:00, ?it/s]08-05 18:27:02 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.76379, ACC: 0.00%
# 1it [00:02,  2.36s/it]08-05 18:27:04 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.60066, ACC: 0.00%
# 2it [00:04,  2.34s/it]08-05 18:27:06 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.40869, ACC: 0.00%
# 3it [00:07,  2.43s/it]08-05 18:27:09 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 13.14399, ACC: 0.00%
# 4it [00:09,  2.47s/it]08-05 18:27:11 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.96128, ACC: 0.00%
# 5it [00:12,  2.47s/it]08-05 18:27:14 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.74375, ACC: 0.00%
# 6it [00:14,  2.42s/it]08-05 18:27:16 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.56939, ACC: 0.00%
# 7it [00:17,  2.45s/it]08-05 18:27:19 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.44230, ACC: 0.00%
# ...

# %%
import torch 
a = torch.ones(2,80,1)
b = torch.zeros(1,80)
c = torch.empty(1,80,1)
e = torch.cat([a,c],dim = 0)
d = c.expand_as(a)
print(a.shape)
print(c.shape)
print(d.shape)
print(e.shape)
# Out:
# torch.Size([2, 80, 1])
# torch.Size([1, 80, 1])
# torch.Size([2, 80, 1])
# torch.Size([3, 80, 1])
