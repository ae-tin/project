# %%
# !nvidia-smi
# Out:
# Wed Aug  3 01:37:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.39       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                  Off |
# | 33%   58C    P2   257W / 260W |  22275MiB / 48601MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel_distill.py
# Out:
# Available devices  5
# Device: cuda:4
# Current cuda device: 4
# 08-03 02:10:18 Model para number = 14.73
# before :  torch.Size([1, 80, 1])
# 0it [00:00, ?it/s]08-03 02:10:20 [ 1] Lr: 0.001000, Training: 0.70%,  Loss: 13.82448, ACC: 0.00%
# 1it [00:01,  1.64s/it]08-03 02:10:21 [ 1] Lr: 0.001000, Training: 1.40%,  Loss: 13.50587, ACC: 0.00%
# 2it [00:03,  1.55s/it]08-03 02:10:23 [ 1] Lr: 0.001000, Training: 2.10%,  Loss: 13.17305, ACC: 0.08%
# 3it [00:04,  1.53s/it]08-03 02:10:24 [ 1] Lr: 0.001000, Training: 2.80%,  Loss: 12.96281, ACC: 0.06%
# 4it [00:06,  1.51s/it]08-03 02:10:26 [ 1] Lr: 0.001000, Training: 3.50%,  Loss: 12.75530, ACC: 0.05%
# 5it [00:07,  1.54s/it]08-03 02:10:27 [ 1] Lr: 0.001000, Training: 4.20%,  Loss: 12.57277, ACC: 0.04%
# 6it [00:09,  1.51s/it]08-03 02:10:29 [ 1] Lr: 0.001000, Training: 4.90%,  Loss: 12.42181, ACC: 0.04%
# 7it [00:10,  1.50s/it]08-03 02:10:30 [ 1] Lr: 0.001000, Training: 5.59%,  Loss: 12.25572, ACC: 0.06%
# ...

# %%
import torch 
a = torch.ones(2,80,1)
b = torch.zeros(1,80)
c = torch.empty(1,80,1)
e = torch.cat([a,c],dim = 0)
d = c.expand_as(a)
print(a.shape)
print(c.shape)
print(d.shape)
print(e.shape)
# Out:
# torch.Size([2, 80, 1])
# torch.Size([1, 80, 1])
# torch.Size([2, 80, 1])
# torch.Size([3, 80, 1])
