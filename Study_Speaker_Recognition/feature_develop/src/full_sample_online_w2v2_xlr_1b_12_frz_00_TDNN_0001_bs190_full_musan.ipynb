# %%
# !nvidia-smi
# Out:
# Tue Feb 21 02:58:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.86.01    Driver Version: 515.86.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro RTX 8000     On   | 00000000:1A:00.0 Off |                    0 |
# | 33%   23C    P8     8W / 260W |      3MiB / 46080MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# !python trainECAPAModel_wav2vec2_tdnn_full_sample.py
# Out:
# Available devices  3
# Device: cuda:0
# Current cuda device: 0
# /Data1/SASV2022/wav2vec2/exps/full_sample_online_w2v2_xlr_1b_12_frz_00_TDNN_0001_bs190_full_musan
# 'HTTPSConnectionPool(host='huggingface.co', port=443): Max retries exceeded with url: /facebook/wav2vec2-xls-r-1b/resolve/main/config.json (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f4abc6b37f0>, 'Connection to huggingface.co timed out. (connect timeout=10)'))' thrown while requesting HEAD https://huggingface.co/facebook/wav2vec2-xls-r-1b/resolve/main/config.json
# ...
