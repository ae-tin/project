# %%
# !python final_first_classification_xgboost_grid.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.09it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]Valid F1 score: 0.7041092739771536
# Valid ROC AUC Score: 0.6809184104725553
# Valid F1 score: 0.7056427336194196
# Valid ROC AUC Score: 0.6823095715289063
#   0%|▏                                        | 1/200 [00:52<2:53:38, 52.36s/it]Valid F1 score: 0.702943948905718
# Valid ROC AUC Score: 0.6809743407381119
# Valid F1 score: 0.7042307890267127
# Valid ROC AUC Score: 0.6823894717455353
# ...
