# %%
# !python first_classification_tabnet_grid.py
# Out:
# Available devices  5
# Device: cuda:2
# Current cuda device: 2
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 14.93it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]epoch 0  | loss: 0.85203 | val_0_auc: 0.58117 |  0:00:21s
# epoch 1  | loss: 0.66706 | val_0_auc: 0.59544 |  0:00:43s
# epoch 2  | loss: 0.66407 | val_0_auc: 0.6226  |  0:01:06s
# epoch 3  | loss: 0.664   | val_0_auc: 0.62744 |  0:01:29s
# epoch 4  | loss: 0.66383 | val_0_auc: 0.6375  |  0:01:52s
# epoch 5  | loss: 0.66188 | val_0_auc: 0.63919 |  0:02:14s
# epoch 6  | loss: 0.65998 | val_0_auc: 0.64092 |  0:02:35s
# epoch 7  | loss: 0.66151 | val_0_auc: 0.64284 |  0:02:57s
# ...
