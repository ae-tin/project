# %%
# !python final_first_classification_xgboost_grid.py
# Out:
# Available devices  5
# Device: cuda:4
# Current cuda device: 4
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.06it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]Valid F1 score: 0.7099150394801513
# Valid ROC AUC Score: 0.6871524119631132
# Valid F1 score: 0.7067034281583644
# Valid ROC AUC Score: 0.6841963864075669
#   0%|▏                                        | 1/200 [00:55<3:03:04, 55.20s/it]Valid F1 score: 0.7095774198692393
# Valid ROC AUC Score: 0.6865340529329681
# Valid F1 score: 0.7074775189045575
# Valid ROC AUC Score: 0.684462383148653
# ...
