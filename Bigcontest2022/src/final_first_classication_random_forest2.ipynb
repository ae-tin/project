# %%
# !python final_first_classification_random_forest_grid.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 20.52it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]parameters :  {'colsample_bynode': 0.8, 'learning_rate': 1, 'max_depth': 6, 'num_parallel_tree': 10, 'objective': 'binary:logistic', 'subsample': 0.8, 'tree_method': 'gpu_hist'} ***** epoch :  30
# [0]	train-logloss:0.61445	eval-logloss:0.61563
# [1]	train-logloss:0.60317	eval-logloss:0.60533
# [2]	train-logloss:0.59828	eval-logloss:0.60071
# [3]	train-logloss:0.59484	eval-logloss:0.59799
# [4]	train-logloss:0.59262	eval-logloss:0.59643
# ...
