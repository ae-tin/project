# %%
# !python first_classification_random_forest_grid.py
# Out:
# Available devices  5
# Device: cuda:1
# Current cuda device: 1
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.99it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]parameters :  {'colsample_bynode': 0.8, 'learning_rate': 1, 'max_depth': 10, 'num_parallel_tree': 10, 'objective': 'binary:logistic', 'subsample': 0.8, 'tree_method': 'gpu_hist'} ***** epoch :  30
# [0]	train-logloss:0.62894	eval-logloss:0.63523
# [1]	train-logloss:0.61983	eval-logloss:0.63173
# [2]	train-logloss:0.61333	eval-logloss:0.63084
# [3]	train-logloss:0.60978	eval-logloss:0.63037
# [4]	train-logloss:0.60569	eval-logloss:0.63014
# [5]	train-logloss:0.60208	eval-logloss:0.63008
# ...
