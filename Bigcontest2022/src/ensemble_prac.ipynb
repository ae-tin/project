# %%
# !python ensemble_1st_2nd_grid.py
# Out:
# Available devices  5
# Device: cuda:2
# Current cuda device: 2
# **************************************************
# 1st classication preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.40it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
# ********************  XGBoost 1st classification is stared!  ********************
# ********************  XGBoost 1st classification is done!  ********************
# ********************  TabNet 1st classification is stared!  ********************
# epoch 0  | loss: 0.67151 | val_0_auc: 0.64285 |  0:00:10s
# epoch 1  | loss: 0.63625 | val_0_auc: 0.68101 |  0:00:20s
# epoch 2  | loss: 0.62972 | val_0_auc: 0.6931  |  0:00:31s
# epoch 3  | loss: 0.62875 | val_0_auc: 0.69148 |  0:00:48s
# epoch 4  | loss: 0.6298  | val_0_auc: 0.69548 |  0:00:58s
# ...
