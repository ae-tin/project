# %%
# !python first_classification_random_forest_grid.py
# Out:
# Available devices  5
# Device: cuda:1
# Current cuda device: 1
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.22it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]parameters :  {'colsample_bynode': 0.8, 'learning_rate': 1, 'max_depth': 8, 'num_parallel_tree': 300, 'objective': 'binary:logistic', 'subsample': 0.8, 'tree_method': 'gpu_hist'} ***** epoch :  50
# [0]	train-logloss:0.63512	eval-logloss:0.63695
# [1]	train-logloss:0.62912	eval-logloss:0.63286
# [2]	train-logloss:0.62611	eval-logloss:0.63156
# [3]	train-logloss:0.62419	eval-logloss:0.63093
# [4]	train-logloss:0.62211	eval-logloss:0.63026
# [5]	train-logloss:0.62033	eval-logloss:0.62979
# ...
