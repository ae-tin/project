# %%
# !python final_first_classification_catboost_grid_.py
# Out:
# Available devices  5
# Device: cuda:1
# Current cuda device: 1
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]****************************************
# params :  {'iterations': 100, 'depth': 4, 'loss_function': 'CrossEntropy', 'leaf_estimation_iterations': 50, 'eval_metric': 'F1', 'logging_level': 'Silent', 'random_seed': 42, 'datatype': 'label_encoding'}
# ****************************************
# ...
# Valid F1 score: 0.6777916840495063
# Valid ROC AUC Score: 0.6484508845088564
# ...
# Valid F1 score: 0.6844168330744768
# Valid ROC AUC Score: 0.644527773571975
#   0%|▏                                        | 1/200 [01:10<3:52:49, 70.20s/it]****************************************
# ...
