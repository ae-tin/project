# %%
# !python final_first_classification_tabnet_grid.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.95it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]epoch 0  | loss: 0.6585  | val_0_auc: 0.60454 |  0:00:13s
# epoch 1  | loss: 0.63904 | val_0_auc: 0.66065 |  0:00:26s
# epoch 2  | loss: 0.63434 | val_0_auc: 0.68913 |  0:00:40s
# epoch 3  | loss: 0.6345  | val_0_auc: 0.69645 |  0:00:53s
# epoch 4  | loss: 0.63308 | val_0_auc: 0.699   |  0:01:06s
# epoch 5  | loss: 0.63184 | val_0_auc: 0.70194 |  0:01:19s
# epoch 6  | loss: 0.62895 | val_0_auc: 0.70673 |  0:01:32s
# epoch 7  | loss: 0.62768 | val_0_auc: 0.70687 |  0:01:44s
# ...
