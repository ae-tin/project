# %%
# !python ensemble_1st_2nd_grid.py
# Out:
# Available devices  5
# Device: cuda:2
# Current cuda device: 2
# **************************************************
# 1st classication preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.44it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
# ********************  XGBoost 1st classification is stared!  ********************
# ********************  XGBoost 1st classification is done!  ********************
# ********************  TabNet 1st classification is stared!  ********************
# epoch 0  | loss: 0.67373 | val_0_auc: 0.65661 |  0:00:10s
# epoch 1  | loss: 0.63588 | val_0_auc: 0.68118 |  0:00:20s
# epoch 2  | loss: 0.6306  | val_0_auc: 0.69372 |  0:00:30s
# epoch 3  | loss: 0.62679 | val_0_auc: 0.70588 |  0:00:40s
# epoch 4  | loss: 0.62324 | val_0_auc: 0.71047 |  0:00:50s
# ...
