# %%
# !python first_classification_xgboost_grid.py
# Out:
# Available devices  5
# Device: cuda:1
# Current cuda device: 1
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.93it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]Valid F1 score: 0.53802610199696
# Valid ROC AUC Score: 0.6187380820491032
# Valid F1 score: 0.5390776656581732
# Valid ROC AUC Score: 0.6195354346564067
#   0%|▏                                          | 1/200 [00:15<51:29, 15.53s/it]Valid F1 score: 0.5318661164603393
# Valid ROC AUC Score: 0.616179311853894
# Valid F1 score: 0.5333145190450572
# Valid ROC AUC Score: 0.6171144039214246
# ...
