# %%
# !python first_classification_tabnet_grid.py
# Out:
# Available devices  5
# Device: cuda:2
# Current cuda device: 2
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 20.87it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]epoch 0  | loss: 0.92594 | val_0_auc: 0.58601 |  0:00:21s
# epoch 1  | loss: 0.66759 | val_0_auc: 0.62241 |  0:00:42s
# epoch 2  | loss: 0.66339 | val_0_auc: 0.63089 |  0:01:03s
# epoch 3  | loss: 0.66111 | val_0_auc: 0.62741 |  0:01:25s
# epoch 4  | loss: 0.65947 | val_0_auc: 0.64125 |  0:01:46s
# epoch 5  | loss: 0.65843 | val_0_auc: 0.6418  |  0:02:08s
# epoch 6  | loss: 0.66303 | val_0_auc: 0.6289  |  0:02:29s
# epoch 7  | loss: 0.66729 | val_0_auc: 0.63333 |  0:02:50s
# ...
