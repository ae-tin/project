# %%
# !python ensemble_1st_2nd_grid.py
# Out:
# Available devices  5
# Device: cuda:4
# Current cuda device: 4
# **************************************************
# 1st classication preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.47it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
# ********************  XGBoost 1st classification is stared!  ********************
# ********************  XGBoost 1st classification is done!  ********************
# ********************  TabNet 1st classification is stared!  ********************
# epoch 0  | loss: 0.6778  | val_0_auc: 0.52347 |  0:00:10s
# epoch 1  | loss: 0.6389  | val_0_auc: 0.6681  |  0:00:19s
# epoch 2  | loss: 0.63197 | val_0_auc: 0.68685 |  0:00:29s
# epoch 3  | loss: 0.62715 | val_0_auc: 0.70373 |  0:00:39s
# epoch 4  | loss: 0.62349 | val_0_auc: 0.71174 |  0:00:49s
# ...
