# %%
# !python first_classification_xgboost_grid.py
# Out:
# Available devices  5
# Device: cuda:1
# Current cuda device: 1
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 14.62it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]Valid F1 score: 0.5439954487466813
# Valid ROC AUC Score: 0.6198626109474986
# Valid F1 score: 0.5433140978441411
# Valid ROC AUC Score: 0.6183311302908293
#   0%|▏                                          | 1/200 [00:17<58:01, 17.50s/it]Valid F1 score: 0.5284816865417377
# Valid ROC AUC Score: 0.6148511848768233
# Valid F1 score: 0.534614681534484
# Valid ROC AUC Score: 0.6155587479230631
# ...
