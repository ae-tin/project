# %%
# !python final_first_classification_tabnet_grid.py
# Out:
# Available devices  5
# Device: cuda:4
# Current cuda device: 4
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.14it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]epoch 0  | loss: 0.62518 | val_0_auc: 0.68119 |  0:00:09s
# epoch 1  | loss: 0.60458 | val_0_auc: 0.71026 |  0:00:18s
# epoch 2  | loss: 0.59914 | val_0_auc: 0.72637 |  0:00:27s
# epoch 3  | loss: 0.59724 | val_0_auc: 0.7357  |  0:00:36s
# epoch 4  | loss: 0.59582 | val_0_auc: 0.74387 |  0:00:45s
# epoch 5  | loss: 0.59424 | val_0_auc: 0.74361 |  0:00:54s
# epoch 6  | loss: 0.59327 | val_0_auc: 0.74484 |  0:01:03s
# epoch 7  | loss: 0.59304 | val_0_auc: 0.74514 |  0:01:12s
# ...
