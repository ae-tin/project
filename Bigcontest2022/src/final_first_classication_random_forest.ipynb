# %%
# !python final_first_classification_random_forest_grid.py
# Out:
# Available devices  5
# Device: cuda:1
# Current cuda device: 1
# **************************************************
# preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.66it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
#   0%|                                                   | 0/200 [00:00<?, ?it/s]parameters :  {'colsample_bynode': 0.8, 'learning_rate': 1, 'max_depth': 10, 'num_parallel_tree': 100, 'objective': 'binary:logistic', 'subsample': 0.8, 'tree_method': 'gpu_hist'} ***** epoch :  50
# [0]	train-logloss:0.59585	eval-logloss:0.60345
# [1]	train-logloss:0.57928	eval-logloss:0.59400
# [2]	train-logloss:0.57047	eval-logloss:0.59083
# [3]	train-logloss:0.56519	eval-logloss:0.58935
# [4]	train-logloss:0.55910	eval-logloss:0.58834
# ...
