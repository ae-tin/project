# %%
# !python ensemble_1st_2nd_grid.py
# Out:
# Available devices  5
# Device: cuda:3
# Current cuda device: 3
# **************************************************
# 1st classication preprocessing,,,,,,
# **************************************************
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 21.13it/s]
# purpose 8
# gender 3
# income_type 6
# employment_type 4
# houseown_type 4
# rehabilitation 4
# ****************** preprocessing end! ******************
# ********************  XGBoost 1st classification is stared!  ********************
# ********************  XGBoost 1st classification is done!  ********************
# ********************  TabNet 1st classification is stared!  ********************
# epoch 0  | loss: 0.67828 | val_0_auc: 0.61984 |  0:00:11s
# epoch 1  | loss: 0.64039 | val_0_auc: 0.67317 |  0:00:21s
# epoch 2  | loss: 0.63534 | val_0_auc: 0.68434 |  0:00:30s
# epoch 3  | loss: 0.63251 | val_0_auc: 0.69388 |  0:00:40s
# epoch 4  | loss: 0.6318  | val_0_auc: 0.69403 |  0:00:50s
# ...
